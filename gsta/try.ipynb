# %%
import torch

# %%
a = torch.randn(11,3,256,256)
a.flatten(0,1)
# Out:
# tensor([[[ 1.6871e-01,  9.3755e-01,  1.5347e+00,  ..., -7.7558e-01,
#           -3.1817e-01,  5.3591e-01],
#          [ 3.8355e-01,  1.6515e+00,  1.3342e+00,  ...,  5.5391e-01,
#            4.8852e-02, -5.2998e-01],
#          [-3.9351e-01,  7.0520e-01,  6.0942e-01,  ...,  1.3603e-01,
#           -1.7976e-01,  1.9767e+00],
#          ...,
#          [-1.3245e+00, -4.5652e-01, -1.1672e+00,  ..., -2.9227e+00,
#            6.6044e-01,  1.0664e+00],
#          [ 2.8898e-01, -2.1482e-01, -2.5175e-01,  ..., -1.6477e+00,
#           -1.6038e-01,  1.5965e+00],
#          [-7.7054e-01, -2.4732e+00,  1.7409e-01,  ...,  9.3341e-01,
#            1.1656e+00, -2.0786e+00]],
#
#         [[ 1.0753e-01,  8.8704e-01, -1.0272e+00,  ..., -2.6494e-01,
#            1.2073e+00,  2.4698e+00],
#          [ 1.4925e+00,  2.8870e-01,  2.2897e-03,  ..., -2.1946e+00,
#            2.7606e+00, -4.6545e-01],
#          [ 1.1273e+00,  1.2588e+00, -7.5417e-02,  ...,  1.0705e+00,
#            2.6770e+00, -1.2135e+00],
# ...

# %%
from torchmetrics.functional import structural_similarity_index_measure

# %%
structural_similarity_index_measure(a,a).item()
# Out:
# tensor(1.)

# %%
a.requires_grad
# Out:
# False
