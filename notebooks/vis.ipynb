# %% [markdown]
# # Visualization

# %%
import torch
import torchmetrics
import imageio.v3 as iio
import numpy as np
import matplotlib.pyplot as plt

# %%
data_dir = "../dataset/"

# %%
plt.imshow(iio.imread(data_dir + "train/video_0/image_21.png"))

# %%
mask = np.load(data_dir + "train/video_0/mask.npy")
print(mask.shape)
plt.imshow(mask[21])
# Out:
# (22, 160, 240)

# %%
jaccard = torchmetrics.JaccardIndex(task="multiclass", num_classes=49)
jaccard(torch.Tensor(mask[0]), torch.Tensor(mask[0]))
# Out:
# tensor(0.1429)

# %%
masks = np.load(data_dir + "train/video_0/mask.npy")
mask = masks[0]
